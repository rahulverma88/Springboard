# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
prod_data = pd.read_csv('EnigmaProductionData.csv')

# %%
prod_data.head()
# Out:
#    File_Number      API_Number     Pool     Date  BBLS_Oil  BBLS_Water  \
# 0         3663  33075002440000  MADISON  05-1999        63          23
# 1         3664  33075002450000  MADISON  05-1999        57          23
# 2         3665  33075002460000  MADISON  05-1999        53           5
# 3         3691  33075002540000  MADISON  05-1999        32        2460
# 4         3693  33075002550000  MADISON  05-1999         0           0
#
#    MCF_Gas  Days_Produced  Oil_Sold  MCF_Sold  MCF_Flared
# 0        0             31         0         0           0
# 1        0             31         0         0           0
# 2        0              7       110         0           0
# 3        0             31         0         0           0
# 4        0              0         0         0           0

# %%
wells = pd.read_csv('EnigmaWells.csv')

# %%
wells.head()
# Out:
#    File_Number      API_Number                   Current_Operator  \
# 0            1  33101000010000           DES LACS WESTERN OIL CO.
# 1            2  33001000010000                         DAVIS WELL
# 2            3  33009000010000  GREAT NORTHERN OIL & GAS PIPELINE
# 3            4  33043000010000                 A. C. TOWNLEY INTS
# 4            5  33031000010000                  GLENFIELD OIL CO.
#
#                      Current_Well_Name                         Lease_Name  \
# 0                               BLUM 1                               BLUM
# 1                         DAVIS WELL 1                         DAVIS WELL
# 2  GREAT NORTH. O AND G PIPELINE CO. 1  GREAT NORTH. O AND G PIPELINE CO.
# 3                 ROBINSON PATD LAND 1                 ROBINSON PATD LAND
# 4              GLENFIELD OIL COMPANY 1              GLENFIELD OIL COMPANY
#
#   Lease_Number                  Original_Operator  \
# 0            1                    PIONEER OIL CO.
# ...

# %%
wells.columns
# Out:
# Index(['File_Number', 'API_Number', 'Current_Operator', 'Current_Well_Name',
#        'Lease_Name', 'Lease_Number', 'Original_Operator', 'Original_Well_Name',
#        'Spud_Date', 'Total_Depth', 'County_Name', 'Township', 'Range',
#        'Section', 'QQ', 'Footages', 'Field_Name', 'Produced_Pools',
#        'Oil_Water_Gas_Cums', 'IPT_Date_Oil_Water_Gas', 'Wellbore', 'Latitude',
#        'Longitude', 'Well_Type', 'Well_Type_Definition', 'Well_Status',
#        'Well_Status_Definition', 'Central_Tank_Battery', 'Well_Status_Date',
#        'Well_Status_Date_Definition'],
#       dtype='object')

# %%
wells.Produced_Pools.unique()
# Out:
# array([nan, 'DEVONIAN,MADISON,SILURIAN', 'MADISON', 'DEVONIAN,MADISON',
#        'SPEARFISH/MADISON', 'DEVONIAN,MADISON,ORDOVICIAN', 'SANISH',
#        'MADISON,MINNELUSA', 'HEATH', 'HEATH,MADISON', 'SPEARFISH/CHARLES',
#        'MADISON,SPEARFISH', 'MADISON,SANISH',
#        'DEVONIAN,ORDOVICIAN,SILURIAN', 'DUPEROW,MADISON',
#        'MADISON,RED RIVER,SILURIAN', 'SILURIAN', 'SPEARFISH',
#        'DEVONIAN,SILURIAN', 'DEVONIAN,SANISH',
#        'DEVONIAN,MADISON,SANISH,SILURIAN', 'RED RIVER', 'DEVONIAN',
#        'BAKKEN', 'DEVONIAN,RED RIVER', 'WINNIPEGOSIS', 'DUPEROW',
#        'ORDOVICIAN', 'BAKKEN,MADISON', 'MADISON,ORDOVICIAN',
#        'BAKKEN/THREE FORKS,BIRDBEAR,MADISON', 'MADISON,RED RIVER',
#        'PIERRE', 'BAKKEN,SILURIAN', 'ORDOVICIAN,SILURIAN',
#        'DEVONIAN,MADISON,SANISH', 'MADISON,MISSION CANYON',
#        'MADISON,ORDOVICIAN,SILURIAN', 'MINNELUSA,ORDOVICIAN,SILURIAN',
#        'DEVONIAN,ORDOVICIAN,SILURIAN,STONEWALL', 'STONEWALL',
# ...

# %%
wells.Produced_Pools.value_counts()
# Out:
# BAKKEN                                             12468
# MADISON                                             5188
# Confidential                                        1572
# RED RIVER                                            387
# SOUTH RED RIVER B                                    277
# SANISH                                               245
# SPEARFISH/CHARLES                                    238
# NORTH RED RIVER B                                    222
# PIERRE                                               197
# HEATH                                                148
# DUPEROW                                              132
# SPEARFISH                                            126
# SPEARFISH/MADISON                                    116
# SILURIAN                                             109
# ORDOVICIAN                                           100
# MADISON,RED RIVER                                     78
# ...

# %%
prod_data.API_Number.nunique()
# Out:
# 16408

# %%
curated_wells = pd.read_csv('EnigmaWells_curated.csv')

# %%
curated_wells.head()
# Out:
#        api_number                      operator_name  \
# 0  33061032100000  OASIS PETROLEUM NORTH AMERICA LLC
# 1  33061032110000  OASIS PETROLEUM NORTH AMERICA LLC
# 2  33023012540000        MUREX PETROLEUM CORPORATION
# 3  33105036080000    WHITING OIL AND GAS CORPORATION
# 4  33105036090000                       ZAVANNA, LLC
#
#                     well_name   latitude   longitude well_status  \
# 0       LANGVED 5393 42-10 4B  48.081885 -102.626053           A
# 1       LANGVED 5393 42-10 5T  48.081885 -102.625918           A
# 2       MACHELLE ANNETTE 8-5H  48.779156 -103.559770           A
# 3  P WOOD 154-98-15-23-15-3HA  48.142543 -103.249392           A
# 4              GUST 2-11 3TFH  48.110455 -103.385458           A
#
#   well_status_code  serialid
# 0                A     21660
# 1                A     21661
# 2                A     21662
# 3                A     21663
# 4                A     21664
