# %% [markdown]
# ## Texas Oil production data
#
# As mentioned earlier, the oil and gas production data has been obtained for three different states - Texas, North Dakota and Wyoming. These states are among the top oil and gas producers in the country. Texas produces even more oil than all the offshore US fields put together.
#
# In this notebook, the Texas data is processed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import listdir

# %% [markdown]
# ### Texas - Railroad Commission of Texas (RRC) data
# This data was provided as a big data dump by Enigma's help desk. This is all stored in the RRCRawData folder. The data are all stored in '.dsv' files, which can be read as a regular csv file, but with '}' separators.
#
# A number of files from the RRC are available, with data aggregated in different ways (only the relevant files will be put on github).

# %%
listdir('./')
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'DataWrangling_TexasOilProd.ipynb',
#  'OG_COUNTY_CYCLE_DATA_TABLE.dsv',
#  'pdq-dump-user-manual_final_ada_1-3-2018.pdf',
#  'TexasOilProdCounty.csv']

# %%
# The county_cycle data table contains historical production aggregated by county
county_cycle = pd.read_csv('OG_COUNTY_CYCLE_DATA_TABLE.dsv',sep='}')

# %% [markdown]
# The county data is modified to add the state FIPS code to the county code, making the code unique for each county

# %%
area_codes = pd.read_csv('../../Unemployment/BLS_AreaCodes.txt',sep='\t',index_col=False)
county_codes = area_codes[area_codes['area_type_code'] == 'F']
county_codes = county_codes.reset_index(drop=True)

# %%
county_codes['FIPS code'] = list(map(lambda x: x[2:7],county_codes.area_code))
county_codes.head()
# Out:
#   area_type_code        area_code           area_text  display_level  \
# 0              F  CN0100100000000  Autauga County, AL              0
# 1              F  CN0100300000000  Baldwin County, AL              0
# 2              F  CN0100500000000  Barbour County, AL              0
# 3              F  CN0100700000000     Bibb County, AL              0
# 4              F  CN0100900000000   Blount County, AL              0
#
#   selectable  sort_sequence FIPS code
# 0          T             31     01001
# 1          T             32     01003
# 2          T             33     01005
# 3          T             34     01007
# 4          T             35     01009

# %%
county_FIPS_names = dict(zip(county_codes['FIPS code'],county_codes['area_text']))

# %%
county_cycle.head()
# Out:
#    COUNTY_NO  DISTRICT_NO  CYCLE_YEAR  CYCLE_MONTH  CYCLE_YEAR_MONTH  \
# 0          1            5        1993            1            199301
# 1          1            5        1993            2            199302
# 2          1            5        1993            3            199303
# 3          1            5        1993            4            199304
# 4          1            5        1993            5            199305
#
#    CNTY_OIL_PROD_VOL  CNTY_OIL_ALLOW  CNTY_OIL_ENDING_BAL  CNTY_GAS_PROD_VOL  \
# 0               7355             NaN                  NaN                  0
# 1               6312             NaN                  NaN                  0
# 2               6222             NaN                  NaN                  0
# 3               6139             NaN                  NaN                  0
# 4               5785             NaN                  NaN                  0
#
#    CNTY_GAS_ALLOW      ...       CNTY_CSGD_PROD_VOL  CNTY_CSGD_LIMIT  \
# 0             NaN      ...                     6347              NaN
# 1             NaN      ...                     4919              NaN
# 2             NaN      ...                     4973              NaN
# 3             NaN      ...                     4410              NaN
# 4             NaN      ...                     5961              NaN
#
#    CNTY_CSGD_GAS_LIFT  CNTY_OIL_TOT_DISP  CNTY_GAS_TOT_DISP  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#    CNTY_COND_TOT_DISP  CNTY_CSGD_TOT_DISP  COUNTY_NAME  DISTRICT_NAME  \
# 0                 NaN                 NaN     ANDERSON             05
# 1                 NaN                 NaN     ANDERSON             05
# 2                 NaN                 NaN     ANDERSON             05
# 3                 NaN                 NaN     ANDERSON             05
# 4                 NaN                 NaN     ANDERSON             05
#
#    OIL_GAS_CODE
# 0             O
# 1             O
# 2             O
# 3             O
# 4             O
#
# [5 rows x 24 columns]

# %% [markdown]
# County numbers greater than 509 do not show up in the Bureau of Labor Statistics' FIPS codes, and are dropped here. They seem to correspond to the RRC's own made-up numbering.

# %%
county_cycle.drop(county_cycle[county_cycle['COUNTY_NO'] > 509].index,inplace=True)

# %%
county_cycle['COUNTY_FIPS_CODE'] = ["48%03d" % x for x in county_cycle.COUNTY_NO]
county_cycle.head()
# Out:
#    COUNTY_NO  DISTRICT_NO  CYCLE_YEAR  CYCLE_MONTH  CYCLE_YEAR_MONTH  \
# 0          1            5        1993            1            199301
# 1          1            5        1993            2            199302
# 2          1            5        1993            3            199303
# 3          1            5        1993            4            199304
# 4          1            5        1993            5            199305
#
#    CNTY_OIL_PROD_VOL  CNTY_OIL_ALLOW  CNTY_OIL_ENDING_BAL  CNTY_GAS_PROD_VOL  \
# 0               7355             NaN                  NaN                  0
# 1               6312             NaN                  NaN                  0
# 2               6222             NaN                  NaN                  0
# 3               6139             NaN                  NaN                  0
# 4               5785             NaN                  NaN                  0
#
#    CNTY_GAS_ALLOW        ...         CNTY_CSGD_LIMIT  CNTY_CSGD_GAS_LIFT  \
# 0             NaN        ...                     NaN                 NaN
# 1             NaN        ...                     NaN                 NaN
# 2             NaN        ...                     NaN                 NaN
# 3             NaN        ...                     NaN                 NaN
# 4             NaN        ...                     NaN                 NaN
#
#    CNTY_OIL_TOT_DISP  CNTY_GAS_TOT_DISP  CNTY_COND_TOT_DISP  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#    CNTY_CSGD_TOT_DISP  COUNTY_NAME  DISTRICT_NAME  OIL_GAS_CODE  \
# 0                 NaN     ANDERSON             05             O
# 1                 NaN     ANDERSON             05             O
# 2                 NaN     ANDERSON             05             O
# 3                 NaN     ANDERSON             05             O
# 4                 NaN     ANDERSON             05             O
#
#    COUNTY_FIPS_CODE
# 0             48001
# 1             48001
# 2             48001
# 3             48001
# 4             48001
#
# [5 rows x 25 columns]

# %%
county_cycle.shape
# Out:
# (172426, 25)

# %%
# map the county FIPS codes to the county names using the dictionary county_FIPS_names
county_cycle['Mapped_Name'] = county_cycle['COUNTY_FIPS_CODE'].map(county_FIPS_names)
county_cycle['TIME'] = pd.to_datetime(county_cycle.CYCLE_YEAR_MONTH,format='%Y%m')

county_cycle.head()
# Out:
#    COUNTY_NO  DISTRICT_NO  CYCLE_YEAR  CYCLE_MONTH  CYCLE_YEAR_MONTH  \
# 0          1            5        1993            1            199301
# 1          1            5        1993            2            199302
# 2          1            5        1993            3            199303
# 3          1            5        1993            4            199304
# 4          1            5        1993            5            199305
#
#    CNTY_OIL_PROD_VOL  CNTY_OIL_ALLOW  CNTY_OIL_ENDING_BAL  CNTY_GAS_PROD_VOL  \
# 0               7355             NaN                  NaN                  0
# 1               6312             NaN                  NaN                  0
# 2               6222             NaN                  NaN                  0
# 3               6139             NaN                  NaN                  0
# 4               5785             NaN                  NaN                  0
#
#    CNTY_GAS_ALLOW    ...      CNTY_OIL_TOT_DISP  CNTY_GAS_TOT_DISP  \
# 0             NaN    ...                    NaN                NaN
# 1             NaN    ...                    NaN                NaN
# 2             NaN    ...                    NaN                NaN
# 3             NaN    ...                    NaN                NaN
# 4             NaN    ...                    NaN                NaN
#
#    CNTY_COND_TOT_DISP  CNTY_CSGD_TOT_DISP  COUNTY_NAME  DISTRICT_NAME  \
# 0                 NaN                 NaN     ANDERSON             05
# 1                 NaN                 NaN     ANDERSON             05
# 2                 NaN                 NaN     ANDERSON             05
# 3                 NaN                 NaN     ANDERSON             05
# 4                 NaN                 NaN     ANDERSON             05
#
#    OIL_GAS_CODE  COUNTY_FIPS_CODE          Mapped_Name       TIME
# 0             O             48001  Anderson County, TX 1993-01-01
# 1             O             48001  Anderson County, TX 1993-02-01
# 2             O             48001  Anderson County, TX 1993-03-01
# 3             O             48001  Anderson County, TX 1993-04-01
# 4             O             48001  Anderson County, TX 1993-05-01
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Missing counties

# %%
county_cycle.COUNTY_NO.nunique() # checking to see the total number of counties is correct: Texas has 254 counties
# Out:
# 240

# %% [markdown]
# This shows that out of 254 counties, 14 have been left out. Here, I find out which counties have missing data.

# %%
kept_names = county_cycle.Mapped_Name.unique()

# %%
tx_county_names = [county_FIPS_names[x] for x in county_FIPS_names if 'TX' in county_FIPS_names[x]]

# %%
len(tx_county_names)
# Out:
# 254

# %% [markdown]
# So the original dictionary had the correct number of counties. Now we can find out which counties were left out in the RRC data.

# %%
set(tx_county_names)-set(kept_names)
# Out:
# {'Bailey County, TX',
#  'Burnet County, TX',
#  'Collin County, TX',
#  'Comal County, TX',
#  'Deaf Smith County, TX',
#  'Delta County, TX',
#  'El Paso County, TX',
#  'Gillespie County, TX',
#  'Hall County, TX',
#  'Lamar County, TX',
#  'Llano County, TX',
#  'Mason County, TX',
#  'Parmer County, TX',
#  'Randall County, TX'}

# %% [markdown]
# These counties have been left out of the RRC data. Note that some of these counties are significant producers of oil and gas. So this dataset is definitely missing some of this key data.

# %% [markdown]
# Here I'm also keeping track of the county FIPS codes which have been left out.

# %%
kept_nums = county_cycle.COUNTY_FIPS_CODE.unique()

# %%
tx_county_nums = [x for x in county_FIPS_names if 'TX' in county_FIPS_names[x]]

# %%
set(tx_county_nums) - set(kept_nums)
# Out:
# {'48017',
#  '48053',
#  '48085',
#  '48091',
#  '48117',
#  '48119',
#  '48141',
#  '48171',
#  '48191',
#  '48277',
#  '48299',
#  '48319',
#  '48369',
#  '48381'}

# %% [markdown]
# ## Final dataframe

# %% [markdown]
# In this project, I have only focused on the oil production. So I will drop the other data.

# %%
# Isolating just the oil production data
county_cycle_oil = county_cycle[['TIME','Mapped_Name','CNTY_OIL_PROD_VOL']]
county_cycle_oil.tail()
# Out:
#              TIME        Mapped_Name  CNTY_OIL_PROD_VOL
# 179013 2017-09-01  Zavala County, TX                  0
# 179014 2017-10-01  Zavala County, TX                  0
# 179015 2017-10-01  Zavala County, TX                  0
# 179016 2017-11-01  Zavala County, TX                  0
# 179017 2017-11-01  Zavala County, TX                  0

# %% [markdown]
# As seen in the above output, some counties have multiple oil production data for the same month. We take the maximum reported oil production in that case.

# %%
county_cycle_oil = county_cycle_oil.rename(columns={'TIME':'Date','Mapped_Name':'County_Name','CNTY_OIL_PROD_VOL':'Oil_Production'})

# %%
county_cycle_oil.Date = pd.to_datetime(county_cycle_oil.Date)

# %%
county_cycle_oil.Date = county_cycle_oil.Date.dt.strftime('%m/%Y')

# %%
county_cycle_oil = county_cycle_oil.groupby(['County_Name','Date']).agg({'Oil_Production':'max'})
county_cycle_oil.tail()
# Out:
#                            Oil_Production
# County_Name       Date
# Zavala County, TX 12/2012          390030
#                   12/2013          544949
#                   12/2014          817685
#                   12/2015          871432
#                   12/2016          612218

# %%
county_cycle_oil.reset_index(inplace=True)

# %%
county_cycle_oil = county_cycle_oil.pivot(index='Date',columns='County_Name',values='Oil_Production')

# %%
county_cycle_oil.head()
# Out:
# County_Name  Anderson County, TX  Andrews County, TX  Angelina County, TX  \
# Date
# 01/1993                 121640.0           2866720.0                132.0
# 01/1994                 110684.0           2846724.0                148.0
# 01/1995                 111589.0           2688326.0                133.0
# 01/1996                 104492.0           2672855.0                193.0
# 01/1997                  97139.0           2544895.0              23488.0
#
# County_Name  Aransas County, TX  Archer County, TX  Armstrong County, TX  \
# Date
# 01/1993                 30998.0           229457.0                   NaN
# 01/1994                 33803.0           214768.0                   NaN
# 01/1995                 28209.0           187377.0                   NaN
# 01/1996                 18207.0           177123.0                   NaN
# 01/1997                 17315.0           163035.0                   NaN
#
# County_Name  Atascosa County, TX  Austin County, TX  Bandera County, TX  \
# Date
# 01/1993                  74280.0            48319.0                 NaN
# 01/1994                  66752.0            45153.0                 NaN
# 01/1995                  60447.0            31324.0                 0.0
# 01/1996                  60092.0            41908.0               295.0
# 01/1997                  58672.0            28653.0               191.0
#
# County_Name  Bastrop County, TX        ...          Willacy County, TX  \
# Date                                   ...
# 01/1993                 19685.0        ...                     72844.0
# 01/1994                 18881.0        ...                     68147.0
# 01/1995                 18120.0        ...                     57598.0
# 01/1996                 15495.0        ...                     54366.0
# 01/1997                 13201.0        ...                     54684.0
#
# County_Name  Williamson County, TX  Wilson County, TX  Winkler County, TX  \
# Date
# 01/1993                      825.0           133441.0            414290.0
# 01/1994                     1423.0            90654.0            391482.0
# 01/1995                      917.0            76739.0            398144.0
# 01/1996                     1239.0            62634.0            394219.0
# 01/1997                     1215.0            43190.0            446820.0
#
# County_Name  Wise County, TX  Wood County, TX  Yoakum County, TX  \
# Date
# 01/1993              82683.0         848809.0          2728824.0
# 01/1994              86178.0         804362.0          2643341.0
# 01/1995              78929.0         707875.0          2576306.0
# 01/1996              64957.0         631908.0          2546692.0
# 01/1997              55618.0         561135.0          2556121.0
#
# County_Name  Young County, TX  Zapata County, TX  Zavala County, TX
# Date
# 01/1993              212978.0             7072.0           256497.0
# 01/1994              188740.0             5587.0           146641.0
# 01/1995              186605.0             5426.0            92445.0
# 01/1996              169412.0             6703.0            68672.0
# 01/1997              162501.0             5147.0            48230.0
#
# [5 rows x 240 columns]

# %% [markdown]
# Now we can add the missing counties. Their production is simply set to 0. I would like the columns to be there as I will ultimately compare all the county oil production data with unemployment and labor force data for all counties. This way, the unemployment and labor force data will not be omitted from the final combined dataframe.

# %% [markdown]
# The NaN values are set to 0, as they are the result of pivoting.

# %%
county_cycle_oil = county_cycle_oil.fillna(0)

# %%
missing_counties = list(set(tx_county_names)-set(kept_names))

# %%
for x in missing_counties:
    county_cycle_oil[x] = np.zeros(len(county_cycle_oil['Anderson County, TX']))

# %%
county_cycle_oil.sort_index(axis=1,inplace=True)

# %%
county_cycle_oil.head()
# Out:
# County_Name  Anderson County, TX  Andrews County, TX  Angelina County, TX  \
# Date
# 01/1993                 121640.0           2866720.0                132.0
# 01/1994                 110684.0           2846724.0                148.0
# 01/1995                 111589.0           2688326.0                133.0
# 01/1996                 104492.0           2672855.0                193.0
# 01/1997                  97139.0           2544895.0              23488.0
#
# County_Name  Aransas County, TX  Archer County, TX  Armstrong County, TX  \
# Date
# 01/1993                 30998.0           229457.0                   0.0
# 01/1994                 33803.0           214768.0                   0.0
# 01/1995                 28209.0           187377.0                   0.0
# 01/1996                 18207.0           177123.0                   0.0
# 01/1997                 17315.0           163035.0                   0.0
#
# County_Name  Atascosa County, TX  Austin County, TX  Bailey County, TX  \
# Date
# 01/1993                  74280.0            48319.0                0.0
# 01/1994                  66752.0            45153.0                0.0
# 01/1995                  60447.0            31324.0                0.0
# 01/1996                  60092.0            41908.0                0.0
# 01/1997                  58672.0            28653.0                0.0
#
# County_Name  Bandera County, TX        ...          Willacy County, TX  \
# Date                                   ...
# 01/1993                     0.0        ...                     72844.0
# 01/1994                     0.0        ...                     68147.0
# 01/1995                     0.0        ...                     57598.0
# 01/1996                   295.0        ...                     54366.0
# 01/1997                   191.0        ...                     54684.0
#
# County_Name  Williamson County, TX  Wilson County, TX  Winkler County, TX  \
# Date
# 01/1993                      825.0           133441.0            414290.0
# 01/1994                     1423.0            90654.0            391482.0
# 01/1995                      917.0            76739.0            398144.0
# 01/1996                     1239.0            62634.0            394219.0
# 01/1997                     1215.0            43190.0            446820.0
#
# County_Name  Wise County, TX  Wood County, TX  Yoakum County, TX  \
# Date
# 01/1993              82683.0         848809.0          2728824.0
# 01/1994              86178.0         804362.0          2643341.0
# 01/1995              78929.0         707875.0          2576306.0
# 01/1996              64957.0         631908.0          2546692.0
# 01/1997              55618.0         561135.0          2556121.0
#
# County_Name  Young County, TX  Zapata County, TX  Zavala County, TX
# Date
# 01/1993              212978.0             7072.0           256497.0
# 01/1994              188740.0             5587.0           146641.0
# 01/1995              186605.0             5426.0            92445.0
# 01/1996              169412.0             6703.0            68672.0
# 01/1997              162501.0             5147.0            48230.0
#
# [5 rows x 254 columns]

# %% [markdown]
# Checking to see the last date for which production has been reported. This is good to keep track of while combining with other dataframes.

# %%
county_cycle_oil.index = pd.to_datetime(county_cycle_oil.index)
county_cycle_oil.sort_index(axis=0,inplace=True)
county_cycle_oil.tail()
# Out:
# County_Name  Anderson County, TX  Andrews County, TX  Angelina County, TX  \
# Date
# 2017-07-01               42772.0           3094031.0                  0.0
# 2017-08-01               42453.0           2914908.0                  0.0
# 2017-09-01                   0.0                 0.0                  0.0
# 2017-10-01                   0.0                 0.0                  0.0
# 2017-11-01                   0.0                 0.0                  0.0
#
# County_Name  Aransas County, TX  Archer County, TX  Armstrong County, TX  \
# Date
# 2017-07-01               3383.0            77206.0                   0.0
# 2017-08-01               2412.0            63253.0                   0.0
# 2017-09-01                  0.0                0.0                   0.0
# 2017-10-01                  0.0                0.0                   0.0
# 2017-11-01                  0.0                0.0                   0.0
#
# County_Name  Atascosa County, TX  Austin County, TX  Bailey County, TX  \
# Date
# 2017-07-01             1586274.0            31191.0                0.0
# 2017-08-01             1423428.0            28304.0                0.0
# 2017-09-01                   0.0                0.0                0.0
# 2017-10-01                   0.0                0.0                0.0
# 2017-11-01                   0.0                0.0                0.0
#
# County_Name  Bandera County, TX        ...          Willacy County, TX  \
# Date                                   ...
# 2017-07-01                122.0        ...                     14024.0
# 2017-08-01                 56.0        ...                     15476.0
# 2017-09-01                  0.0        ...                         0.0
# 2017-10-01                  0.0        ...                         0.0
# 2017-11-01                  0.0        ...                         0.0
#
# County_Name  Williamson County, TX  Wilson County, TX  Winkler County, TX  \
# Date
# 2017-07-01                   713.0           117169.0            615249.0
# 2017-08-01                   631.0            90852.0            509957.0
# 2017-09-01                     0.0                0.0                 0.0
# 2017-10-01                     0.0                0.0                 0.0
# 2017-11-01                     0.0                0.0                 0.0
#
# County_Name  Wise County, TX  Wood County, TX  Yoakum County, TX  \
# Date
# 2017-07-01           14494.0         275487.0          2008449.0
# 2017-08-01           11303.0         258891.0          1939632.0
# 2017-09-01               0.0              0.0                0.0
# 2017-10-01               0.0              0.0                0.0
# 2017-11-01               0.0              0.0                0.0
#
# County_Name  Young County, TX  Zapata County, TX  Zavala County, TX
# Date
# 2017-07-01            78763.0             4542.0           514086.0
# 2017-08-01            77334.0             4724.0           468779.0
# 2017-09-01                0.0                0.0                0.0
# 2017-10-01                0.0                0.0                0.0
# 2017-11-01                0.0                0.0                0.0
#
# [5 rows x 254 columns]

# %% [markdown]
# Eliminating 2017, as those values seem to be weird in places:

# %%
county_cycle_oil = county_cycle_oil.loc[:'2016-12-01']

# %%
county_cycle_oil.tail()
# Out:
# County_Name  Anderson County, TX  Andrews County, TX  Angelina County, TX  \
# Date
# 2016-08-01               47221.0           2989914.0                  0.0
# 2016-09-01               44144.0           2978563.0                  0.0
# 2016-10-01               46425.0           3102870.0                  0.0
# 2016-11-01               45678.0           2939942.0                  0.0
# 2016-12-01               46477.0           2882062.0                  0.0
#
# County_Name  Aransas County, TX  Archer County, TX  Armstrong County, TX  \
# Date
# 2016-08-01               3484.0            87147.0                   0.0
# 2016-09-01               3339.0            81275.0                   0.0
# 2016-10-01               3585.0            84378.0                   0.0
# 2016-11-01               3077.0            78413.0                   0.0
# 2016-12-01               3545.0            81196.0                   0.0
#
# County_Name  Atascosa County, TX  Austin County, TX  Bailey County, TX  \
# Date
# 2016-08-01             1608203.0            35242.0                0.0
# 2016-09-01             1546479.0            32845.0                0.0
# 2016-10-01             1706671.0            35824.0                0.0
# 2016-11-01             1600728.0            31736.0                0.0
# 2016-12-01             1594355.0            32321.0                0.0
#
# County_Name  Bandera County, TX        ...          Willacy County, TX  \
# Date                                   ...
# 2016-08-01                 93.0        ...                     17654.0
# 2016-09-01                 90.0        ...                     16603.0
# 2016-10-01                 96.0        ...                     18138.0
# 2016-11-01                151.0        ...                     14754.0
# 2016-12-01                 35.0        ...                     17185.0
#
# County_Name  Williamson County, TX  Wilson County, TX  Winkler County, TX  \
# Date
# 2016-08-01                   686.0           135399.0            484328.0
# 2016-09-01                   817.0           124777.0            521024.0
# 2016-10-01                   524.0           130192.0            619251.0
# 2016-11-01                   644.0           122064.0            587838.0
# 2016-12-01                   569.0           120549.0            571039.0
#
# County_Name  Wise County, TX  Wood County, TX  Yoakum County, TX  \
# Date
# 2016-08-01           16324.0         294673.0          1956900.0
# 2016-09-01           15842.0         280943.0          1884683.0
# 2016-10-01           17180.0         277868.0          1978785.0
# 2016-11-01           15573.0         281104.0          1871260.0
# 2016-12-01           16431.0         308243.0          1922891.0
#
# County_Name  Young County, TX  Zapata County, TX  Zavala County, TX
# Date
# 2016-08-01            79573.0             6461.0           647237.0
# 2016-09-01            77034.0             5196.0           623681.0
# 2016-10-01            79918.0             5930.0           625078.0
# 2016-11-01            76406.0             5486.0           596527.0
# 2016-12-01            78893.0             5880.0           612218.0
#
# [5 rows x 254 columns]

# %%
county_cycle_oil.to_csv('TexasOilProdCounty.csv')
